# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/skin-cancer8/tensorflow2/default/1/Skin Cancer8.keras
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/1269.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/623.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/820.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/1354.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/45.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/369.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/1711.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/1173.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/1488.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/436.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/1409.jpg
# /kaggle/input/skin-cancer-malignant-vs-benign/data/test/benign/71.jpg
# ...

# %%
# !pip uninstall -y jax jaxlib
# !pip install --upgrade --force-reinstall tensorflow
# Out:
# Found existing installation: jax 0.4.33
# Uninstalling jax-0.4.33:
#   Successfully uninstalled jax-0.4.33
# Found existing installation: jaxlib 0.4.33
# Uninstalling jaxlib-0.4.33:
#   Successfully uninstalled jaxlib-0.4.33
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 MB 2.6 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 100.4 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 86.0 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 81.5 MB/s eta 0:00:00:00:0100:01
# ...

# %%
train_data=os.listdir("/kaggle/input/skin-cancer-malignant-vs-benign/train")
test_data=os.listdir("/kaggle/input/skin-cancer-malignant-vs-benign/test")

cancer_types_train_data=[]
train_labels=[]
for item in train_data:
  all_categ_train=os.listdir('/kaggle/input/skin-cancer-malignant-vs-benign/train'+'/'+item)
  filenames=[j for j in os.listdir('/kaggle/input/skin-cancer-malignant-vs-benign/train'+'/'+item) if j.endswith('.jpg')]
  for f in filenames:
    image_path = os.path.join('/kaggle/input/skin-cancer-malignant-vs-benign/train'+'/'+item, f)
    cancer_types_train_data.append((item,image_path))
    train_labels.append(item)
print(cancer_types_train_data)
# Out:
# [('benign', '/kaggle/input/skin-cancer-malignant-vs-benign/train/benign/764.jpg'), ('benign', '/kaggle/input/skin-cancer-malignant-vs-benign/train/benign/1700.jpg'), ('benign', '/kaggle/input/skin-cancer-malignant-vs-benign/train/benign/1786.jpg'), ('benign', '/kaggle/input/skin-cancer-malignant-vs-benign/train/benign/1075.jpg'), ('benign', '/kaggle/input/skin-cancer-malignant-vs-benign/train/benign/771.jpg'), ('benign', '/kaggle/input/skin-cancer-malignant-vs-benign/train/benign/208.jpg'), ('benign', '/kaggle/input/skin-cancer-malignant-vs-benign/train/benign/1789.jpg'), ('benign', '/kaggle/input/skin-cancer-malignant-vs-benign/train/benign/473.jpg'), ('benign', '/kaggle/input/skin-cancer-malignant-vs-benign/train/benign/1792.jpg'), ('benign', '/kaggle/input/skin-cancer-malignant-vs-benign/train/benign/1411.jpg'), ('benign', '/kaggle/input/skin-cancer-malignant-vs-benign/train/benign/1031.jpg'), ('benign', '/kaggle/input/skin-cancer-malignant-vs-benign/train/benign/1749.jpg'), ('ben
# ...

# %%
cancer_types_test_data=[]
test_labels=[]
for item in test_data:
  all_categ_test=os.listdir(str('/kaggle/input/skin-cancer-malignant-vs-benign/test'+'/'+item))
  print(all_categ_test[:])
  filenames=[j for j in os.listdir('/kaggle/input/skin-cancer-malignant-vs-benign/test'+'/'+item) if j.endswith('.jpg')]
  for f in filenames:
    image_path = os.path.join('/kaggle/input/skin-cancer-malignant-vs-benign/test'+'/'+item, f)
    cancer_types_test_data.append((item,image_path))
    test_labels.append(item)
print(cancer_types_test_data)
# Out:
# ['1269.jpg', '623.jpg', '820.jpg', '1354.jpg', '45.jpg', '369.jpg', '1711.jpg', '1173.jpg', '1488.jpg', '436.jpg', '1409.jpg', '71.jpg', '1055.jpg', '215.jpg', '185.jpg', '1025.jpg', '1343.jpg', '1579.jpg', '717.jpg', '1473.jpg', '253.jpg', '1166.jpg', '626.jpg', '1443.jpg', '5.jpg', '1559.jpg', '824.jpg', '1376.jpg', '1297.jpg', '8.jpg', '892.jpg', '1655.jpg', '84.jpg', '751.jpg', '944.jpg', '237.jpg', '273.jpg', '289.jpg', '1125.jpg', '768.jpg', '1134.jpg', '1243.jpg', '1499.jpg', '668.jpg', '97.jpg', '806.jpg', '1401.jpg', '211.jpg', '1648.jpg', '291.jpg', '1019.jpg', '10.jpg', '54.jpg', '251.jpg', '916.jpg', '1183.jpg', '558.jpg', '1118.jpg', '998.jpg', '1592.jpg', '1018.jpg', '61.jpg', '1191.jpg', '1359.jpg', '427.jpg', '1200.jpg', '819.jpg', '379.jpg', '1288.jpg', '313.jpg', '1310.jpg', '1080.jpg', '98.jpg', '527.jpg', '580.jpg', '1710.jpg', '1471.jpg', '256.jpg', '1034.jpg', '559.jpg', '1634.jpg', '57.jpg', '1146.jpg', '894.jpg', '690.jpg', '664.jpg', '388.jpg', '1044.jpg', '1
# ...

# %%
print(len(cancer_types_test_data))
# Out:
# 660

# %%
test_labels.extend(train_labels)
df_labels=test_labels
print(len(df_labels))
# Out:
# 3297

# %%
cancer_df_train=pd.DataFrame(data=cancer_types_train_data,columns=['cancer_type','image_path'])
cancer_df_train
# Out:
#      cancer_type                                         image_path
# 0         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 2         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 3         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 4         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# ...          ...                                                ...
# 2632   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 2633   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 2634   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 2635   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 2636   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
#
# [2637 rows x 2 columns]

# %%
cancer_df_test=pd.DataFrame(data=cancer_types_test_data,columns=['cancer_type','image_path'])
cancer_df_test
# Out:
#     cancer_type                                         image_path
# 0        benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1        benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 2        benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 3        benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 4        benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# ..          ...                                                ...
# 655   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 656   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 657   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 658   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 659   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
#
# [660 rows x 2 columns]

# %%
df=pd.concat([cancer_df_train,cancer_df_test])
df
# Out:
#     cancer_type                                         image_path
# 0        benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1        benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 2        benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 3        benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 4        benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# ..          ...                                                ...
# 655   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 656   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 657   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 658   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 659   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
#
# [3297 rows x 2 columns]

# %%
from collections import Counter
import math
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
import numpy as np
import os
from PIL import Image
import pandas as pd
import random

# STEP 1: Simulate Imbalanced Dataset (benign > malignant)
malignant_df = df[df['cancer_type'] == 'malignant']
benign_df = df[df['cancer_type'] == 'benign']
df_imbalanced = pd.concat([benign_df, malignant_df], ignore_index=True)

print(f"Simulated Imbalanced dataset length: {len(df_imbalanced)}")
print(f"Simulated class distribution: {Counter(df_imbalanced['cancer_type'])}")

# Replace df with the imbalanced version
df = df_imbalanced

# STEP 2: Create ImageDataGenerator for augmentation
augmentor = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# STEP 3: Count classes
labels_counter = Counter(df['cancer_type'])
num_benign = labels_counter.get('benign', 0)
num_malignant = labels_counter.get('malignant', 0)

print(f"Before Augmentation: {num_benign} benign vs {num_malignant} malignant")

# STEP 4: Compute needed augmentations
additional_malignant_needed = num_benign - num_malignant

if additional_malignant_needed > 0:
    malignant_images_paths = df[df['cancer_type'] == 'malignant']['image_path'].tolist()
    augment_copies_per_image = math.ceil(additional_malignant_needed / len(malignant_images_paths))

    print(f"Augmenting ~{augment_copies_per_image} copies per malignant image")

    augmented_images = []
    save_dir = '/kaggle/working/augmented/malignant'
    os.makedirs(save_dir, exist_ok=True)

    count = 0
    for img_idx, img_path in enumerate(malignant_images_paths):
        img = load_img(img_path)
        img_array = img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)

        aug_iter = augmentor.flow(img_array, batch_size=1)

        for _ in range(augment_copies_per_image):
            aug_img_array = next(aug_iter)[0].astype('uint8')
            img_pil = Image.fromarray(aug_img_array)

            save_path = os.path.join(save_dir, f'aug_malignant_{count}.jpg')
            img_pil.save(save_path)

            augmented_images.append({'cancer_type': 'malignant', 'image_path': save_path})
            count += 1

            if count >= additional_malignant_needed:
                break
        if count >= additional_malignant_needed:
            break

    print(f"Number of augmented malignant images generated: {len(augmented_images)}")

    df_augmented = pd.DataFrame(augmented_images)
    df = pd.concat([df, df_augmented], ignore_index=True)

else:
    print("No augmentation needed, classes are already balanced.")

# STEP 5: Final Summary
print(f"Final dataset length: {len(df)}")
print(f"Final class distribution: {Counter(df['cancer_type'])}")
# Out:
# Simulated Imbalanced dataset length: 3297
# Simulated class distribution: Counter({'benign': 1800, 'malignant': 1497})
# Before Augmentation: 1800 benign vs 1497 malignant
# Augmenting ~1 copies per malignant image
# Number of augmented malignant images generated: 303
# Final dataset length: 3600
# Final class distribution: Counter({'benign': 1800, 'malignant': 1800})

# %%
df
# Out:
#      cancer_type                                         image_path
# 0         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 2         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 3         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 4         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# ...          ...                                                ...
# 3595   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3596   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3597   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3598   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3599   malignant  /kaggle/working/augmented/malignant/aug_malign...
#
# [3600 rows x 2 columns]

# %%
df_benign=df[df['cancer_type']=='benign']
df_benign
# Out:
#      cancer_type                                         image_path
# 0         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 2         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 3         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 4         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# ...          ...                                                ...
# 1795      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1796      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1797      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1798      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1799      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
#
# [1800 rows x 2 columns]

# %%
df_malignant=df[df['cancer_type']=='malignant']
df_malignant
# Out:
#      cancer_type                                         image_path
# 1800   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1801   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1802   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1803   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1804   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# ...          ...                                                ...
# 3595   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3596   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3597   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3598   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3599   malignant  /kaggle/working/augmented/malignant/aug_malign...
#
# [1800 rows x 2 columns]

# %%
df_train_benign=df_benign[:1750]
df_train_benign
# Out:
#      cancer_type                                         image_path
# 0         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 2         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 3         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 4         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# ...          ...                                                ...
# 1745      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1746      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1747      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1748      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1749      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
#
# [1750 rows x 2 columns]

# %%
df_train_malignant=df_malignant[:1750]
df_train_malignant
# Out:
#      cancer_type                                         image_path
# 1800   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1801   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1802   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1803   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1804   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# ...          ...                                                ...
# 3545   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3546   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3547   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3548   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3549   malignant  /kaggle/working/augmented/malignant/aug_malign...
#
# [1750 rows x 2 columns]

# %%
df_train=pd.concat([df_train_benign,df_train_malignant])
df_train= df_train.sample(frac=1).reset_index(drop=True)
print(df_train)
# Out:
#      cancer_type                                         image_path
# 0         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1      malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 2      malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 3         benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 4      malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# ...          ...                                                ...
# 3495      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 3496      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 3497   malignant  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 3498   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3499      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
#
# [3500 rows x 2 columns]

# %%
df_test_benign=df_benign[1750:]
df_test_benign
# Out:
#      cancer_type                                         image_path
# 1750      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1751      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1752      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1753      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1754      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1755      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1756      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1757      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1758      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1759      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1760      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1761      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1762      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# ...

# %%
df_test_malignant=df_malignant[1750:]
df_test_malignant
# Out:
#      cancer_type                                         image_path
# 3550   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3551   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3552   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3553   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3554   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3555   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3556   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3557   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3558   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3559   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3560   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3561   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3562   malignant  /kaggle/working/augmented/malignant/aug_malign...
# ...

# %%
df_test=pd.concat([df_test_benign,df_test_malignant])
df_test= df_test.sample(frac=1).reset_index(drop=True)
print(df_test)
# Out:
#    cancer_type                                         image_path
# 0       benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 1       benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 2    malignant  /kaggle/working/augmented/malignant/aug_malign...
# 3    malignant  /kaggle/working/augmented/malignant/aug_malign...
# 4       benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# ..         ...                                                ...
# 95      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
# 96   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 97   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 98   malignant  /kaggle/working/augmented/malignant/aug_malign...
# 99      benign  /kaggle/input/skin-cancer-malignant-vs-benign/...
#
# [100 rows x 2 columns]

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Augmentation for the training data
train_data_gen = ImageDataGenerator(
    rescale=1.0/255.0,                # Normalize pixel values to [0, 1]
    rotation_range=30,            # Rotate images up to 20 degrees
    width_shift_range=0.2,        # Shift width by 20%
    height_shift_range=0.2,       # Shift height by 20%
    shear_range=0.2,             # Apply shearing transformations
    zoom_range=0.2,               # Randomly zoom in/out
    horizontal_flip=True,         # Flip images horizontally
    fill_mode='nearest',          # Fill missing pixels after transformations

)

# Minimal augmentation for validation data (only rescaling)
val_data_gen = ImageDataGenerator(
    rescale=1.0/255.0,                # Normalize pixel values to [0, 1]
    validation_split=0.2,  # Important!

)

test_data_gen = ImageDataGenerator(rescale=1.0/255.0)

# Training generator with augmentations
train_generator = train_data_gen.flow_from_dataframe(
    dataframe=df_train,                  # DataFrame containing image paths and labels
    x_col='image_path',            # Column with image file paths
    y_col='cancer_type',             # Column with labels
    target_size=(224, 224),        # Resize images to 224x224
    class_mode='categorical',      # Multi-class classification
    batch_size=16,                 # Number of images per batch
    subset='training',             # Use as training data
    shuffle=True  ,
    validation_split=0.2,  # Important!
    seed=1
)

# Validation generator with minimal augmentation
validation_generator = val_data_gen.flow_from_dataframe(
    dataframe=df_train,
    x_col='image_path',
    y_col='cancer_type',
    target_size=(224,224),
    class_mode='categorical',
    batch_size=16,
    subset='validation',          # Use as validation data
    shuffle=True ,                # No shuffle for consistent validation
    seed=1
)



test_generator = test_data_gen.flow_from_dataframe(
    dataframe=df_test,               # A separate test dataframe
    x_col='image_path',
    y_col='cancer_type',            # You can also set y_col=None if doing inference only
    target_size=(224, 224),
    class_mode='categorical',       # Or 'input' / None if not evaluating labels
    batch_size=16,
    shuffle=False                   # Important for matching predictions with inputs
)

print("Class Indices: ", train_generator.class_indices)
print("Class Indices: ", validation_generator.class_indices)
print("Class Indices: ", test_generator.class_indices)
# Out:
# Found 3500 validated image filenames belonging to 2 classes.
# Found 700 validated image filenames belonging to 2 classes.
# Found 100 validated image filenames belonging to 2 classes.
# Class Indices:  {'benign': 0, 'malignant': 1}
# Class Indices:  {'benign': 0, 'malignant': 1}
# Class Indices:  {'benign': 0, 'malignant': 1}

# %%
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout,BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras import layers, models
import tensorflow as tf 
from tensorflow.keras import layers, models 
from tensorflow.keras.regularizers import L2
from tensorflow.keras.applications import MobileNet

base_model = MobileNet(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in base_model.layers[:-5]:
    layer.trainable = False    # Freeze the base model

model = Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(1024, activation='relu', kernel_regularizer=L2(0.03)),
    layers.Dropout(0.3),
    layers.Dense(512, activation='relu', kernel_regularizer=L2(0.03)),
    layers.Dropout(0.3),
    layers.Dense(2, activation='softmax')  # Adjust the number of classes
])


model.summary()
# Out:
# ...
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ mobilenet_1.00_224 (Functional)      │ (None, 7, 7, 1024)          │       3,228,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1024)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1024)                │       1,049,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
import tensorflow as tf
model=tf.keras.models.load_model('/kaggle/input/skin-cancer8/tensorflow2/default/1/Skin Cancer8.keras')

# %%
from tensorflow.keras.optimizers import Adam
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight
import numpy as np


# Set EarlyStopping callback with patience=5


# Enhanced Callbacks
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    verbose=1)

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    start_from_epoch=0
)
# Add callbacks to training

# Train the model
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=50,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    shuffle=False,
    callbacks=[lr_scheduler, early_stopping]
)
# Out:
# Epoch 1/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 50s 203ms/step - accuracy: 0.7263 - loss: 44.9303 - val_accuracy: 0.6977 - val_loss: 27.8667 - learning_rate: 1.0000e-04
# Epoch 2/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6667 - loss: 27.6510 - val_accuracy: 0.6948 - val_loss: 27.7888 - learning_rate: 1.0000e-04
# Epoch 3/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 42s 195ms/step - accuracy: 0.8374 - loss: 23.5985 - val_accuracy: 0.7340 - val_loss: 14.5345 - learning_rate: 1.0000e-04
# Epoch 4/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9167 - loss: 14.1599 - val_accuracy: 0.7326 - val_loss: 14.4938 - learning_rate: 1.0000e-04
# Epoch 5/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 42s 193ms/step - accuracy: 0.8482 - loss: 12.2792 - val_accuracy: 0.8517 - val_loss: 7.5022 - learning_rate: 1.0000e-04
# Epoch 6/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9167 - loss: 7.4307 - val_accuracy: 0.8517 - val_loss: 7.4789 - learning_rate: 1.0000e-04
# Epoch 7/50
# ...

# %%
print("Evaluating model...")
train_loss, train_accuracy = model.evaluate(train_generator, steps=train_generator.samples // train_generator.batch_size)
print(f"training Accuracy: {train_accuracy * 100:.2f}%")

print("Evaluating model...")
val_loss, val_accuracy = model.evaluate(validation_generator, steps=validation_generator.samples // validation_generator.batch_size)
print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")

test_loss, test_accuracy = model.evaluate(test_generator, steps=test_generator.samples // test_generator.batch_size)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Evaluating model...
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 57s 244ms/step - accuracy: 0.9354 - loss: 0.2023
# training Accuracy: 93.06%
# Evaluating model...
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9389 - loss: 0.2006
# Validation Accuracy: 93.17%
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9823 - loss: 0.1241
# Test Accuracy: 96.88%

# %%
for layer in base_model.layers[-70:]:
    layer.trainable = True    #Unfreeze the base model



# Lower learning rate for fine-tuning
model.compile(
    optimizer = Adam(learning_rate=0.00001),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
reduce_lr= ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=3,
    min_lr=1e-8,
    verbose=1
)


early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    start_from_epoch=0
)
# Continue training
fine_tune_epochs = 100
history_fine = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=fine_tune_epochs,
    steps_per_epoch=train_generator.samples // 16,
    validation_steps=validation_generator.samples // 16,
    shuffle=False,
    callbacks=[reduce_lr,early_stopping]
)
# Out:
# Epoch 1/100
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 63s 208ms/step - accuracy: 0.8775 - loss: 0.3149 - val_accuracy: 0.9491 - val_loss: 0.2147 - learning_rate: 1.0000e-05
# Epoch 2/100
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9167 - loss: 0.2383 - val_accuracy: 0.9491 - val_loss: 0.2146 - learning_rate: 1.0000e-05
# Epoch 3/100
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 43s 197ms/step - accuracy: 0.8974 - loss: 0.2956 - val_accuracy: 0.9259 - val_loss: 0.2220 - learning_rate: 1.0000e-05
# Epoch 4/100
#   1/218 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.9167 - loss: 0.2792
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9167 - loss: 0.2792 - val_accuracy: 0.9259 - val_loss: 0.2207 - learning_rate: 1.0000e-05
# Epoch 5/100
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 44s 201ms/step - accuracy: 0.8904 - loss: 0.2931 - val_accuracy: 0.9375 - val_loss: 0.2043 - learning_rate: 5.0000e-06
# Epoch 6/100
# ...

# %%
print("Evaluating model...")
train_loss, train_accuracy = model.evaluate(train_generator, steps=train_generator.samples // train_generator.batch_size)
print(f"training Accuracy: {train_accuracy * 100:.2f}%")

print("Evaluating model...")
val_loss, val_accuracy = model.evaluate(validation_generator, steps=validation_generator.samples // validation_generator.batch_size)
print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")

test_loss, test_accuracy = model.evaluate(test_generator, steps=test_generator.samples // test_generator.batch_size)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Evaluating model...
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 44s 190ms/step - accuracy: 0.9203 - loss: 0.2249
# training Accuracy: 92.63%
# Evaluating model...
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9336 - loss: 0.2216
# Validation Accuracy: 93.31%
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9823 - loss: 0.1241
# Test Accuracy: 96.88%

# %%
# Get predictions on the whole test set
pred_probs = model.predict(test_generator, verbose=1)

# Get predicted labels
y_pred = np.argmax(pred_probs, axis=1)      # get class index with highest probability

# Now get true labels (will match since we predict on all data)
y_true = test_generator.classes  # works if you're using flow_from_directory or flow_from_dataframe
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 402ms/step

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[47  3]
#  [ 0 50]]

# %%
print(df_test['cancer_type'].value_counts())
# Out:
# cancer_type
# benign       50
# malignant    50
# Name: count, dtype: int64

# %%
model.save('Skin Cancer8.keras')

# %%
file_paths = [test_generator.directory + '/' + fname for fname in test_generator.filenames]
x=[]
for path in file_paths:
    x.append(path)
print(x)
# Out:
# ['//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/689.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1135.jpg', '//kaggle/working/augmented/malignant/aug_malignant_294.jpg', '//kaggle/working/augmented/malignant/aug_malignant_258.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1516.jpg', '//kaggle/working/augmented/malignant/aug_malignant_285.jpg', '//kaggle/working/augmented/malignant/aug_malignant_295.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1578.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/647.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/428.jpg', '//kaggle/working/augmented/malignant/aug_malignant_276.jpg', '//kaggle/working/augmented/malignant/aug_malignant_297.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/457.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1321.jpg', '//kaggle/working/augmented/malignant/aug_malignant_254.jpg',
# ...

# %%
print(len(file_paths))
# Out:
# 100

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet import preprocess_input
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import tensorflow as tf

def arg_translator(predictions):
    arr=np.array(predictions[0])
    result = ' , '.join(map(str, arr))
    arr = [float(x) for x in result.split(' , ')]
    max1=np.argmax(arr)
    return max1


# Function to preprocess the image and predict
def preprocess_and_predict1(image_path, model):
    img = image.load_img(image_path, target_size=(224, 224))  # Resize
    img_array = image.img_to_array(img)  # Convert to array
    img_array = preprocess_input(img_array)  # Normalize input for MobileNet
    img_array = tf.expand_dims(img_array, axis=0)  # Add batch dimension
    predictions = model.predict(img_array)
    class_labels=['Benign','Malignant']
    predicted_label = class_labels[arg_translator(predictions)]
    return predicted_label


# Function to preprocess the image and predict
def preprocess_and_predict(image_path, model):
    img = image.load_img(image_path, target_size=(224, 224))  # Resize
    img_array = image.img_to_array(img)  # Convert to array
    img_array = preprocess_input(img_array)  # Normalize input for MobileNet
    img_array = tf.expand_dims(img_array, axis=0)  # Add batch dimension

    # Get model prediction
     # Get model prediction
    threshold1 = 0.3  # Increase the threshold to be more confident
    threshold2 = 0.6
    predictions = model.predict(img_array)
    predicted_label = 'Benign' if predictions[0][0] > threshold1 or predictions[0][1]<threshold2 else 'Malignant'
    return predicted_label


# Function to evaluate the model and calculate precision, recall, F1-score
def evaluate_model(test_image_urls, model):
    y_true = []  # List of true labels (Benign or Malignant)
    y_pred = []  # List of predicted labels (Benign or Malignant)
    
    # Loop through all images and make predictions
    for image_url in test_image_urls:
        # Extract the actual label from the URL (e.g., 'malignant' or 'benign')
        class_label_from_url = os.path.basename(os.path.dirname(image_url)).lower()
        
        # Get the predicted label
        predicted_label = preprocess_and_predict(image_url, model)
        predicted_label_normalized = predicted_label.lower()
        
        # Append the true label and predicted label to lists
        y_true.append(class_label_from_url)
        y_pred.append(predicted_label_normalized)
    
    # Calculate precision, recall, and F1-score
    precision = precision_score(y_true, y_pred, average='binary', pos_label='malignant')
    recall = recall_score(y_true, y_pred, average='binary', pos_label='malignant')
    f1 = f1_score(y_true, y_pred, average='binary', pos_label='malignant')

    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred, labels=['benign', 'malignant'])

    return precision, recall, f1, cm

# Example: List of image URLs (replace this with your actual test image paths)
test_image_urls =['//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/689.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1135.jpg', '//kaggle/working/augmented/malignant/aug_malignant_294.jpg', '//kaggle/working/augmented/malignant/aug_malignant_258.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1516.jpg', '//kaggle/working/augmented/malignant/aug_malignant_285.jpg', '//kaggle/working/augmented/malignant/aug_malignant_295.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1578.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/647.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/428.jpg', '//kaggle/working/augmented/malignant/aug_malignant_276.jpg', '//kaggle/working/augmented/malignant/aug_malignant_297.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/457.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1321.jpg', '//kaggle/working/augmented/malignant/aug_malignant_254.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1747.jpg', '//kaggle/working/augmented/malignant/aug_malignant_298.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1377.jpg', '//kaggle/working/augmented/malignant/aug_malignant_274.jpg', '//kaggle/working/augmented/malignant/aug_malignant_275.jpg', '//kaggle/working/augmented/malignant/aug_malignant_282.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/335.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1226.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/304.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1576.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/367.jpg', '//kaggle/working/augmented/malignant/aug_malignant_288.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/823.jpg', '//kaggle/working/augmented/malignant/aug_malignant_272.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1143.jpg', '//kaggle/working/augmented/malignant/aug_malignant_265.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1445.jpg', '//kaggle/working/augmented/malignant/aug_malignant_266.jpg', '//kaggle/working/augmented/malignant/aug_malignant_290.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1757.jpg', '//kaggle/working/augmented/malignant/aug_malignant_302.jpg', '//kaggle/working/augmented/malignant/aug_malignant_283.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1276.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1538.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/454.jpg', '//kaggle/working/augmented/malignant/aug_malignant_300.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/147.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1265.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1521.jpg', '//kaggle/working/augmented/malignant/aug_malignant_280.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1602.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1334.jpg', '//kaggle/working/augmented/malignant/aug_malignant_284.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1061.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/268.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/962.jpg', '//kaggle/working/augmented/malignant/aug_malignant_263.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1115.jpg', '//kaggle/working/augmented/malignant/aug_malignant_292.jpg', '//kaggle/working/augmented/malignant/aug_malignant_260.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1155.jpg', '//kaggle/working/augmented/malignant/aug_malignant_278.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/90.jpg', '//kaggle/working/augmented/malignant/aug_malignant_264.jpg', '//kaggle/working/augmented/malignant/aug_malignant_279.jpg', '//kaggle/working/augmented/malignant/aug_malignant_287.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1768.jpg', '//kaggle/working/augmented/malignant/aug_malignant_253.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/2.jpg', '//kaggle/working/augmented/malignant/aug_malignant_296.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/635.jpg', '//kaggle/working/augmented/malignant/aug_malignant_286.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1322.jpg', '//kaggle/working/augmented/malignant/aug_malignant_256.jpg', '//kaggle/working/augmented/malignant/aug_malignant_257.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/226.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/433.jpg', '//kaggle/working/augmented/malignant/aug_malignant_271.jpg', '//kaggle/working/augmented/malignant/aug_malignant_277.jpg', '//kaggle/working/augmented/malignant/aug_malignant_270.jpg', '//kaggle/working/augmented/malignant/aug_malignant_261.jpg', '//kaggle/working/augmented/malignant/aug_malignant_269.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1357.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/462.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/830.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1530.jpg', '//kaggle/working/augmented/malignant/aug_malignant_273.jpg', '//kaggle/working/augmented/malignant/aug_malignant_291.jpg', '//kaggle/working/augmented/malignant/aug_malignant_281.jpg', '//kaggle/working/augmented/malignant/aug_malignant_299.jpg', '//kaggle/working/augmented/malignant/aug_malignant_293.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/925.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1367.jpg', '//kaggle/working/augmented/malignant/aug_malignant_262.jpg', '//kaggle/working/augmented/malignant/aug_malignant_255.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1253.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/18.jpg', '//kaggle/working/augmented/malignant/aug_malignant_301.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/205.jpg', '//kaggle/working/augmented/malignant/aug_malignant_289.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1537.jpg', '//kaggle/working/augmented/malignant/aug_malignant_268.jpg', '//kaggle/working/augmented/malignant/aug_malignant_259.jpg', '//kaggle/working/augmented/malignant/aug_malignant_267.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/245.jpg']
precision,recall,f1,cm=evaluate_model(test_image_urls ,model)
# Display the results
print(f"Precision: {precision * 100:.2f}%")
print(f"Recall: {recall * 100:.2f}%")
print(f"F1 Score: {f1 * 100:.2f}%")
print("Confusion Matrix:")
print(cm)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# ...

# %%
def count_correct_predictions(image_urls):
    correct_predictions = 0
    
    for image_url in image_urls:
        # Extract the actual label from the URL (e.g., 'malignant' or 'benign')
        class_label_from_url = os.path.basename(os.path.dirname(image_url)).lower()
        
        # Get the predicted label
        predicted_label = preprocess_and_predict(image_url,model)
        predicted_label_normalized = predicted_label.lower()
        
        # Compare and count correct predictions
        if predicted_label_normalized == class_label_from_url:
            correct_predictions += 1

    return correct_predictions

# List of image URLs (you can replace this with your actual test image paths)
test_image_urls =['//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/689.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1135.jpg', '//kaggle/working/augmented/malignant/aug_malignant_294.jpg', '//kaggle/working/augmented/malignant/aug_malignant_258.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1516.jpg', '//kaggle/working/augmented/malignant/aug_malignant_285.jpg', '//kaggle/working/augmented/malignant/aug_malignant_295.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1578.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/647.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/428.jpg', '//kaggle/working/augmented/malignant/aug_malignant_276.jpg', '//kaggle/working/augmented/malignant/aug_malignant_297.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/457.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1321.jpg', '//kaggle/working/augmented/malignant/aug_malignant_254.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1747.jpg', '//kaggle/working/augmented/malignant/aug_malignant_298.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1377.jpg', '//kaggle/working/augmented/malignant/aug_malignant_274.jpg', '//kaggle/working/augmented/malignant/aug_malignant_275.jpg', '//kaggle/working/augmented/malignant/aug_malignant_282.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/335.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1226.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/304.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1576.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/367.jpg', '//kaggle/working/augmented/malignant/aug_malignant_288.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/823.jpg', '//kaggle/working/augmented/malignant/aug_malignant_272.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1143.jpg', '//kaggle/working/augmented/malignant/aug_malignant_265.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1445.jpg', '//kaggle/working/augmented/malignant/aug_malignant_266.jpg', '//kaggle/working/augmented/malignant/aug_malignant_290.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1757.jpg', '//kaggle/working/augmented/malignant/aug_malignant_302.jpg', '//kaggle/working/augmented/malignant/aug_malignant_283.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1276.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1538.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/454.jpg', '//kaggle/working/augmented/malignant/aug_malignant_300.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/147.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1265.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1521.jpg', '//kaggle/working/augmented/malignant/aug_malignant_280.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1602.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1334.jpg', '//kaggle/working/augmented/malignant/aug_malignant_284.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1061.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/268.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/962.jpg', '//kaggle/working/augmented/malignant/aug_malignant_263.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1115.jpg', '//kaggle/working/augmented/malignant/aug_malignant_292.jpg', '//kaggle/working/augmented/malignant/aug_malignant_260.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1155.jpg', '//kaggle/working/augmented/malignant/aug_malignant_278.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/90.jpg', '//kaggle/working/augmented/malignant/aug_malignant_264.jpg', '//kaggle/working/augmented/malignant/aug_malignant_279.jpg', '//kaggle/working/augmented/malignant/aug_malignant_287.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1768.jpg', '//kaggle/working/augmented/malignant/aug_malignant_253.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/2.jpg', '//kaggle/working/augmented/malignant/aug_malignant_296.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/635.jpg', '//kaggle/working/augmented/malignant/aug_malignant_286.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1322.jpg', '//kaggle/working/augmented/malignant/aug_malignant_256.jpg', '//kaggle/working/augmented/malignant/aug_malignant_257.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/226.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/433.jpg', '//kaggle/working/augmented/malignant/aug_malignant_271.jpg', '//kaggle/working/augmented/malignant/aug_malignant_277.jpg', '//kaggle/working/augmented/malignant/aug_malignant_270.jpg', '//kaggle/working/augmented/malignant/aug_malignant_261.jpg', '//kaggle/working/augmented/malignant/aug_malignant_269.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1357.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/462.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/830.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1530.jpg', '//kaggle/working/augmented/malignant/aug_malignant_273.jpg', '//kaggle/working/augmented/malignant/aug_malignant_291.jpg', '//kaggle/working/augmented/malignant/aug_malignant_281.jpg', '//kaggle/working/augmented/malignant/aug_malignant_299.jpg', '//kaggle/working/augmented/malignant/aug_malignant_293.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/925.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1367.jpg', '//kaggle/working/augmented/malignant/aug_malignant_262.jpg', '//kaggle/working/augmented/malignant/aug_malignant_255.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1253.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/18.jpg', '//kaggle/working/augmented/malignant/aug_malignant_301.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/205.jpg', '//kaggle/working/augmented/malignant/aug_malignant_289.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/1537.jpg', '//kaggle/working/augmented/malignant/aug_malignant_268.jpg', '//kaggle/working/augmented/malignant/aug_malignant_259.jpg', '//kaggle/working/augmented/malignant/aug_malignant_267.jpg', '//kaggle/input/skin-cancer-malignant-vs-benign/test/benign/245.jpg']
# Count correct predictions
correct_predictions = count_correct_predictions(test_image_urls)
print(f"Number of correct predictions: {correct_predictions}/{len(test_image_urls)}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# ...

# %%
image_path=input("please enter image path: \n")
result=preprocess_and_predict(image_path,model)
print(result)
# Out:
# please enter image path:
#  /kaggle/input/picture/1746099356299.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Malignant
